# %% [markdown]
# # B3

# %%
import arrow
from influxdb import InfluxDBClient

from numpy import array
import math

from pprint import pprint
from ast import literal_eval

# %%
client = InfluxDBClient('luna')
tstart = None
results = client.query('SELECT island_id,best_f,round FROM champion', database='com.how2cell.sabaody.biopredyn.b3-driver.f397d243-ede8-49b6-aa41-9e4ab0ebd629')
# pprint(results)
for result in results:
    for point in result:
        t = arrow.get(point['time'])
        if tstart == None or t < tstart:
            tstart = t
timepoints_by_island = {}
min_f = None
best_x = None
t_f = None
island_ids = set()
for result in results:
    for point in result:
        t = arrow.get(point['time'])-tstart
        round = int(point['round'])
        island_id = point['island_id']
        if not island_id in island_ids:
            island_ids.add(island_id)
        best_f = literal_eval(point['best_f'])[0]
#         best_f = 1./literal_eval(point['best_f'])[0]
        if min_f is None or best_f < min_f:
            min_f = best_f
        if t_f is None or t > t_f:
            t_f = t
#             best_x = literal_eval(point['best_x'])
        best_f = math.log10(literal_eval(point['best_f'])[0])
        x = t.days*24.+t.seconds/3600.
#         x = round
        timepoints_by_island.setdefault(island_id, []).append((x,best_f))
        # print(t.seconds,island_id,best_f)
print(island_ids)
print(len(island_ids))
print('t_f',t_f.days)
        
import tellurium as te
for island_id,series in timepoints_by_island.items():
    trace = array(sorted(series, key=lambda t: t[0]))
    te.plot(trace[:,0], trace[:,1], tag='first', name='16 islands', show=False)

# min_f1 = min_f
# q = 'SELECT island_id,best_f,best_x,round FROM champion WHERE round >= 1999'
# results = client.query(q, database='com.how2cell.sabaody.biopredyn.b3-driver.f397d243-ede8-49b6-aa41-9e4ab0ebd629')

# min_f = None
# for result in results:
#     for point in result:
#         best_x = literal_eval(point['best_x'])
#         if min_f is None or best_f < min_f:
#             min_f = best_f
#             best_x = literal_eval(point['best_x'])
    
print('first min obj',min_f)
print(best_x)

# %%
client = InfluxDBClient('luna')
tstart = None
results = client.query('SELECT island_id,best_f,round FROM champion', database='com.how2cell.sabaody.biopredyn.b3-driver.fd3caad8-b063-4a56-add2-ec19096a0de4')
# pprint(results)
for result in results:
    for point in result:
        t = arrow.get(point['time'])
        if tstart == None or t < tstart:
            tstart = t
timepoints_by_island = {}
min_f = None
best_x = None
island_ids = set()
for result in results:
    for point in result:
        t = arrow.get(point['time'])-tstart
        round = int(point['round'])
        island_id = point['island_id']
        if not island_id in island_ids:
            island_ids.add(island_id)
        best_f = literal_eval(point['best_f'])[0]
#         best_f = 1./literal_eval(point['best_f'])[0]
        if min_f is None or best_f < min_f:
            min_f = best_f
#             best_x = literal_eval(point['best_x'])
        best_f = math.log10(literal_eval(point['best_f'])[0])
        x = t.days*24.+t.seconds/3600.
#         x = round
        timepoints_by_island.setdefault(island_id, []).append((x,best_f))
        # print(t.seconds,island_id,best_f)
print(island_ids)
print(len(island_ids))
        
import tellurium as te
for island_id,series in timepoints_by_island.items():
    trace = array(sorted(series, key=lambda t: t[0]))
    te.plot(trace[:,0], trace[:,1], tag='1 island', name='1 island', show=False)

# %%
client = InfluxDBClient('luna')
tstart = None
results = client.query('SELECT island_id,best_f,round FROM champion', database='com.how2cell.sabaody.biopredyn.b3-driver.aaf810fe-df5a-44de-806c-0ef4f9993ba0')
# pprint(results)
for result in results:
    for point in result:
        t = arrow.get(point['time'])
        if tstart == None or t < tstart:
            tstart = t
timepoints_by_island = {}
min_f = None
best_x = None
island_ids = set()
for result in results:
    for point in result:
        t = arrow.get(point['time'])-tstart
        round = int(point['round'])
        island_id = point['island_id']
        if not island_id in island_ids:
            island_ids.add(island_id)
        best_f = literal_eval(point['best_f'])[0]
#         best_f = 1./literal_eval(point['best_f'])[0]
        if min_f is None or best_f < min_f:
            min_f = best_f
#             best_x = literal_eval(point['best_x'])
        best_f = math.log10(literal_eval(point['best_f'])[0])
        x = t.days*24+t.seconds/3600.
#         x = round
        timepoints_by_island.setdefault(island_id, []).append((x,best_f))
        # print(t.seconds,island_id,best_f)
print(island_ids)
print(len(island_ids))
        
import tellurium as te
for island_id,series in timepoints_by_island.items():
    trace = array(sorted(series, key=lambda t: t[0]))
    te.plot(trace[:,0], trace[:,1], tag='8 islands', name='8 islands', show=False)

# %%
client = InfluxDBClient('luna')
tstart = None
results = client.query('SELECT island_id,best_f,round FROM champion', database='com.how2cell.sabaody.biopredyn.b3-driver.0c5f77b4-fc2f-44f7-9dcf-2a1ec7cf8d98')
# pprint(results)
for result in results:
    for point in result:
        t = arrow.get(point['time'])
        if tstart == None or t < tstart:
            tstart = t
print('tstart', tstart)
timepoints_by_island = {}
min_f = None
best_x = None
island_ids = set()
t_f = None
for result in results:
    for point in result:
        t = arrow.get(point['time'])-tstart
        round = int(point['round'])
        island_id = point['island_id']
        if not island_id in island_ids:
            island_ids.add(island_id)
        best_f = literal_eval(point['best_f'])[0]
#         best_f = 1./literal_eval(point['best_f'])[0]
        if min_f is None or best_f < min_f:
            min_f = best_f
        if t_f is None or t > t_f:
            t_f = t
#             best_x = literal_eval(point['best_x'])
        best_f = math.log10(literal_eval(point['best_f'])[0])
        x = t.days*24.+t.seconds/3600.
#         x = round
        timepoints_by_island.setdefault(island_id, []).append((x,best_f))
        # print(t.seconds,island_id,best_f)
print(island_ids)
print(len(island_ids))
print(t_f.days)
        
import tellurium as te
for island_id,series in timepoints_by_island.items():
    trace = array(sorted(series, key=lambda t: t[0]))
    te.plot(trace[:,0], trace[:,1], tag='4 islands', name='4 islands', show=False)

# %%
client = InfluxDBClient('luna')
tstart = None
results = client.query('SELECT island_id,best_f,round FROM champion', database='com.how2cell.sabaody.biopredyn.b3-driver.1f21669e-3dec-45ab-9bdc-f75632e87ebc')
# pprint(results)
for result in results:
    for point in result:
        t = arrow.get(point['time'])
        if tstart == None or t < tstart:
            tstart = t
timepoints_by_island = {}
min_f = None
best_x = None
island_ids = set()
for result in results:
    for point in result:
        t = arrow.get(point['time'])-tstart
        round = int(point['round'])
        island_id = point['island_id']
        if not island_id in island_ids:
            island_ids.add(island_id)
        best_f = literal_eval(point['best_f'])[0]
#         best_f = 1./literal_eval(point['best_f'])[0]
        if min_f is None or best_f < min_f:
            min_f = best_f
#             best_x = literal_eval(point['best_x'])
        best_f = math.log10(literal_eval(point['best_f'])[0])
        x = t.days*24.+t.seconds/3600.
#         x = round
        timepoints_by_island.setdefault(island_id, []).append((x,best_f))
        # print(t.seconds,island_id,best_f)
print(island_ids)
print(len(island_ids))
        
import tellurium as te
for island_id,series in timepoints_by_island.items():
    trace = array(sorted(series, key=lambda t: t[0]))
    te.plot(trace[:,0], trace[:,1], tag='2 islands', name='2 islands', show=False)

# %%
te.show()
